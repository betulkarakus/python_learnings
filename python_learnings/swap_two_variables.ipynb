# %% [markdown]
# # Description:
# This program demonstrates how to swap the values of two variables without using a temporary variable.

# %%
# Input variables
a = 5
b = 10

# Display the original values
print("Before swapping:")
print("a =", a)
print("b =", b)

# Swapping without a temporary variable
a, b = b, a

# Display the swapped values
print("\nAfter swapping:")
print("a =", a)
print("b =", b)
# Out:
# Before swapping:
# a = 5
# b = 10
#
# After swapping:
# a = 10
# b = 5
