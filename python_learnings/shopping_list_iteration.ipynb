# %%
# Given shopping list
shopping_list = ["Apple", "Cheese", "Yogurt", "Cola"]

# Iterate through the shopping list using index
for index in range(0, len(shopping_list)):
    # Retrieve the item at the current index
    item_purchased = shopping_list[index]

    # Print the purchased item
    print(item_purchased)
# Out:
# Apple
# Cheese
# Yogurt
# Cola
