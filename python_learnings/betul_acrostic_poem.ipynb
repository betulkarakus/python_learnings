# %% [markdown]
# # Description:
# This Python code defines a variable 'betul_acrostic' containing an acrostic poem for the name "Betul."
# Each line of the poem starts with a letter from the name, forming a descriptive and positive portrayal.

# %%
# Define the acrostic poem for the name "Betul"
betul_acrostic = """
Bright smiles, a beacon of joy,
Elegance in every step, oh so coy.
Tenderhearted, with kindness to share,
Unwavering spirit, beyond compare.
Luminous grace in each gesture.
"""

# Print the acrostic poem
print(betul_acrostic)
# Out:
# Bright smiles, a beacon of joy,
# Elegance in every step, oh so coy.
# Tenderhearted, with kindness to share,
# Unwavering spirit, beyond compare.
# Luminous grace in each gesture.
