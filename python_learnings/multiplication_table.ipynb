# %%
def multiplication_table(number, table_size):
    print(f"Multiplication Table for {number}")
    print("-" * 30)

    for i in range(1, table_size + 1):
        result = number * i
        print(f"{number} x {i} = {result}")

    print("-" * 30)
    print("Table complete!")

if __name__ == "__main__":
    # Get user input for the number and table size
    number = int(input("Enter the number for the multiplication table: "))
    table_size = int(input("Enter the table size: "))

    # Display the multiplication table
    multiplication_table(number, table_size)
# Out:
# Enter the number for the multiplication table: 5
# Enter the table size: 10
# Multiplication Table for 5
# ------------------------------
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# ------------------------------
# Table complete!
