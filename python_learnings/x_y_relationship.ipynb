# %%
# Input section
# Get values for x and y from the user
x = int(input("Enter the value for x: "))
y = int(input("Enter the value for y: "))

# Comparison and output
# Compare the values of x and y and print the appropriate message
if x < y:
    print("x is less than y")
elif x > y:
    print("x is greater than y")
else:
    print("x and y are equal")

# Display the end of the program
print("End of the program")
# Out:
# Enter the value for x: 45
# Enter the value for y: 66
# x is less than y
# End of the program
