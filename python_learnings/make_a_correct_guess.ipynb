# %%
import random

# Choose a random number between 1 and 100
number = random.randint(1, 100)

# Determine the number the user needs to guess
guess = False

# Repeat the loop until the user makes a correct guess
while guess != number:
    # Ask the user for a number input
    guess = int(input("Enter a number between 1 and 100: "))

    # Check the accuracy of the guess
    if guess == number:
        print("Congratulations! Correct guess!")
    elif guess < number:
        print("Enter a larger number.")
    else:
        print("Enter a smaller number.")
# Out:
# Enter a number between 1 and 100: 34
# Enter a larger number.
# Enter a number between 1 and 100: 56
# Enter a larger number.
# Enter a number between 1 and 100: 77
# Enter a smaller number.
# Enter a number between 1 and 100: 67
# Enter a larger number.
# Enter a number between 1 and 100: 69
# Congratulations! Correct guess!
